# %%
import numpy as np
import pandas as pd
df=pd.DataFrame({
    'length':[1.5,0.5,1.2,0.9,3],
    'width':[0.7,0.2,0.15,0.2,1.1]
}, index=['pig','rabbit','duck','chicken','horse'])
hist=df.hist(bins=3)

# %%
import matplotlib.pyplot as plt
d=np.random.uniform(0,40,100)
n, bins, patches=plt.hist(x=d, bins='auto', color='#0504aa', alpha=0.7, rwidth=0.85)
plt.grid(axis='y',alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('My very own histogram')
plt.text(23, 45, r'$\mu=15, \sigma=3$')
maxfreq=n.max()
plt.ylim(ymax=np.ceil(maxfreq/10)*10 if maxfreq % 10 else maxfreq+10)
# Out:
# (0.0, 20.0)

# %%
data = pd.read_excel('15_OLDFAITH.xls')

# Create a DataFrame
df = pd.DataFrame(data)

# Plot histogram for 'Duration' (Old Faithful Eruption Duration)
plt.hist(df['Duration'], bins='auto', color='#0504aa', alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Duration (giây)')
plt.ylabel('Frequency')
plt.title('Histogram of Old Faithful Eruption Duration (Dataset 15)')
plt.show()

# %%
diet_coke_weight = np.random.uniform(0.5, 2.5, 100)
plt.hist(x=diet_coke_weight, bins='auto', color='#ff5733', alpha=0.7, rwidth=0.85)
plt.xlabel('Weight (pounds)')
plt.ylabel('Frequency')
plt.title('Diet Coke Weight Distribution (Pounds)')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset (adjust the file path as needed)
data = pd.read_excel('17_COLA.xls')

# Histogram for Diet Coke Weight
plt.subplot(1, 2, 2)
plt.hist(data['CKDIETWT'], bins=20, color='orange', alpha=0.7)
plt.title('Histogram cho trọng lượng của Diet Coke')
plt.xlabel('Trọng lượng (pounds)')
plt.ylabel('Tần suất')

plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
df=pd.DataFrame([[5.1, 3.5, 0],
                [4.9, 3.0, 0],
                [7.0, 3.2, 1],
                [6.4, 3.2, 1],
                [5.9, 3.0, 2]],
                columns=['length', 'width', 'species'])

ax1=df.plot.scatter(x='length', y='width', c='DarkBlue')

# %%
#tạo data
N=500
x=np.random.rand(N)
y=np.random.rand(N)
colors=(0,0,0)
area=np.pi*3
#plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22316\1025380239.py:8: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x, y, s=area, c=colors, alpha=0.5)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_excel('04_CIGARET.xls')
plt.scatter(df['KgTar'], df['KgCO'], np.pi*3, color='#0504aa', alpha=1)
plt.title('MQH giữa Tar và CO')
plt.xlabel('Tar (kg)')
plt.ylabel('CO (kg)')
plt.grid(True)

# %%
df=pd.read_excel('12_ELECTRIC.xls').head(22)
plt.scatter(df['AvTemp'], df['kWh'], np.pi*3, color='#0504aa', alpha=1)
plt.title('MQH AvTemp và kwh')
plt.xlabel('AvTemp (celsius)')
plt.ylabel('kwh')
plt.grid(True)

# %%
df=pd.DataFrame({'lab':['A', 'B', 'C'], 'val':[10,20,30]})
ax=df.plot.bar(x='lab', y='val', rot=0)

# %%
speed=[0.1,17.5,40,48,52,69,88]
lifespan=[2,8,70,1.5,25,12,28]
index=['snail','pig','elephant','rabbit','giraffe','coyote','horse']
df=pd.DataFrame({'speed':speed, 'lifespan':lifespan}, index=index)
ax=df.plot.bar(rot=0)

# %%
plt.rcdefaults()
objects=('Python','C++','Java','Perl','Scala','Lisp')
y_pos=np.arange(len(objects))
performance=[10,8,6,4,2,1]

plt.bar(y_pos,performance,align='center',alpha=0.5)
plt.xticks(y_pos,objects)
plt.ylabel('Usage')
plt.title('Programming language usage')
plt.show()

# %%
labels=('Public 2-Year', 'Public 4-Year', 'Private 2-Year', 'Private 4-Year')
performance=[36.8, 40, 1.6, 21.9]
plt.bar(labels, performance, align='center', color='#0504aa', alpha=0.5)
plt.ylabel('Frequency (%)')
plt.title('Relative frequency of colleges')
# Out:
# Text(0.5, 1.0, 'Relative frequency of colleges')

# %%
labels=['Public 2-Year', 'Public 4-Year', 'Private 2-Year', 'Private 4-Year']
sizes=[36.8, 40, 1.6, 21.9]
colors=['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
# Out:
# (np.float64(-1.0999975557335093),
#  np.float64(1.0999986975120546),
#  np.float64(-1.099994453330734),
#  np.float64(1.0999997358728921))

# %%
df=pd.read_excel('02_BODYTEMP.xlsx')
data=df['DAY 2 - 12AM']
mean_value=np.mean(data)
print(mean_value)
data_clean=data.dropna()
median_value=np.median(data_clean)
print(median_value)
# Out:
# 98.19999999999999
# 98.4

# %%
min_value=np.min(data)
max_value=np.max(data)
varian_value=np.var(data)
std_value=np.std(data)
print(min_value)
print(max_value)
print(varian_value)
print(std_value)
# Out:
# 96.5
# 99.6
# 0.3843396226415095
# 0.6199513066697332
